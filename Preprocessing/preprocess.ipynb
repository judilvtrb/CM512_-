# %%
import pandas as pd

def convert_list_column_to_binary(df, column_name):
    """
    將包含列表的欄位轉換為多個二元（yes/no）欄位
    
    Parameters:
    df: DataFrame
    column_name: 要處理的欄位名稱
    
    Returns:
    DataFrame: 處理後的 DataFrame
    """
    # 創建臨時列表欄位
    temp_col_name = f'{column_name}_list'
    df[temp_col_name] = df[column_name].str.strip('[]').str.replace("'", "").str.split(', ')
    
    # 獲取所有可能的項目
    all_items = set()
    for items in df[temp_col_name].dropna():
        if isinstance(items, list):
            all_items.update(items)
    
    # 為每個項目創建新的欄位
    for item in all_items:
        # 創建合法的欄位名稱（移除特殊字符）
        clean_item = item.replace(' ', '_').replace('&', 'and')
        df[f'{column_name}_{clean_item}'] = df[temp_col_name].apply(
            lambda x: 'yes' if isinstance(x, list) and item in x else 'no'
        )
    
    # 刪除臨時欄位
    df = df.drop(temp_col_name, axis=1)
    
    return df, sorted(all_items)

# 讀取 CSV 文件
df = pd.read_csv('hostels_original.csv')

# 處理所有指定的欄位
columns_to_process = ['Free', 'General', 'Services', 'Food & Drink', 'Entertainment']

# 存儲每個類別的項目，用於後續查看
items_by_category = {}

# 處理每個欄位
for column in columns_to_process:
    df, items = convert_list_column_to_binary(df, column)
    items_by_category[column] = items

# 儲存結果
df.to_csv('hostels_processed.csv', index=False)

# 打印每個類別的所有項目（可選）
for category, items in items_by_category.items():
    print(f"\n{category} 類別的所有項目：")
    for item in items:
        print(f"- {item}")

# 檢查結果（可選）
# 對於每個類別，顯示原始欄位和新增的欄位的前幾行
for category in columns_to_process:
    print(f"\n{category} 相關欄位的前幾行：")
    related_columns = [category] + [col for col in df.columns if col.startswith(f'{category}_')]
    print(df[related_columns].head())
# Out:
# Free 類別的所有項目：
# - Free Airport Transfer
# - Free Breakfast
# - Free City Maps
# - Free City Tour
# - Free Internet Access
# - Free Parking
# - Free WiFi
# - Linen Included
# - Towels Included
#
# General 類別的所有項目：
# - "Childrens Play Area"
# - Adaptors
# - Air Conditioning
# - BBQ
# - Bicycle Parking
# - Book Exchange
# - Breakfast Not Included
# - Cable TV
# - Card Phones
# - Ceiling Fan
# - Common Room
# - Cooker
# - Dishwasher
# - Dryer
# - Elevator
# - Fitness Centre
# - Flexible NRR
# - Follows Covid-19 sanitation guidance
# - Fridge/Freezer
# - Hair Dryers
# - Hair Dryers For Hire
# - Hot Showers
# - Hot Tub
# - Iron / Ironing Board
# - Jobs Board
# - Key Card Access
# - Linen Not Included
# - Meeting Rooms
# - Microwave
# - Outdoor Terrace
# - Parking
# - Reading Light
# - Safe Deposit Box
# - Security Lockers
# - Self-Catering Facilities
# - Towels Not Included
# - Utensils
# - Washing Machine
# - Wheelchair Friendly
#
# Services 類別的所有項目：
# - 24 Hour Reception
# - 24 Hour Security
# - Beauty Salon
# - Bicycle Hire
# - Currency Exchange
# - Express check-in / out
# - Fax Service
# - Housekeeping
# - Internet Access
# - Internet café
# - Late check-out
# - Laundry Facilities
# - Luggage Storage
# - Postal Service
# - Reception (limited hours)
# - Tours/Travel Desk
# - Towels for hire
# - Wake-up calls
#
# Food & Drink 類別的所有項目：
# - Bar
# - Cafe
# - Café
# - Meals Available
# - Restaurant
# - Tea & Coffee Making Facilities
# - Vending Machines
#
# Entertainment 類別的所有項目：
# - "DVDs"
# - Board Games
# - Foosball
# - Games Room
# - PlayStation
# - Pool Table
# - Wi-Fi
# - Wii
#
# Free 相關欄位的前幾行：
#                                                 Free Free_Free_Breakfast  \
# 0  ['Free City Maps', 'Free Internet Access', 'Fr...                  no
# 1                                                NaN                  no
# 2  ['Free Breakfast', 'Free City Maps', 'Free Int...                 yes
# 3  ['Free City Maps', 'Free Internet Access', 'Fr...                  no
# 4  ['Free City Maps', 'Free Internet Access', 'Fr...                  no
#
#   Free_Free_Parking Free_Free_City_Maps Free_Free_WiFi Free_Free_City_Tour  \
# 0                no                 yes            yes                  no
# 1                no                  no             no                  no
# 2                no                 yes            yes                  no
# 3                no                 yes            yes                  no
# 4                no                 yes            yes                  no
#
#   Free_Linen_Included Free_Free_Internet_Access Free_Towels_Included  \
# 0                 yes                       yes                   no
# 1                  no                        no                   no
# 2                 yes                       yes                   no
# 3                 yes                       yes                   no
# 4                 yes                       yes                   no
#
#   Free_Free_Airport_Transfer
# 0                         no
# 1                         no
# 2                         no
# 3                         no
# 4                         no
#
# General 相關欄位的前幾行：
#                                              General General_Outdoor_Terrace  \
# 0  ['Adaptors', 'Air Conditioning', 'Bicycle Park...                      no
# 1  ['Air Conditioning', 'Elevator', 'Follows Covi...                      no
# 2  ['Adaptors', 'Air Conditioning', 'Bicycle Park...                     yes
# 3  ['Adaptors', 'Air Conditioning', 'Bicycle Park...                      no
# 4  ['Adaptors', 'Air Conditioning', 'Bicycle Park...                     yes
#
#   General_Washing_Machine General_Card_Phones General_Iron_/_Ironing_Board  \
# 0                     yes                  no                          yes
# 1                     yes                  no                           no
# 2                     yes                  no                          yes
# 3                     yes                  no                           no
# 4                     yes                 yes                          yes
#
#   General_Hair_Dryers_For_Hire General_Utensils General_Towels_Not_Included  \
# 0                           no               no                          no
# 1                           no               no                         yes
# 2                           no              yes                          no
# 3                          yes               no                          no
# 4                           no              yes                          no
#
#   General_Meeting_Rooms General_Common_Room  ... General_Fridge/Freezer  \
# 0                   yes                 yes  ...                    yes
# 1                    no                  no  ...                    yes
# 2                   yes                 yes  ...                    yes
# 3                   yes                 yes  ...                     no
# 4                    no                 yes  ...                    yes
#
#   General_Fitness_Centre General_Hot_Showers General_Dryer  \
# 0                     no                 yes           yes
# 1                     no                 yes            no
# 2                     no                 yes           yes
# 3                     no                 yes            no
# 4                     no                 yes           yes
#
#   General_Breakfast_Not_Included General_Parking General_BBQ  \
# 0                            yes              no          no
# 1                             no              no          no
# 2                             no              no          no
# 3                             no              no          no
# 4                             no             yes          no
#
#   General_"Childrens_Play_Area" General_Dishwasher General_Hot_Tub
# 0                            no                 no              no
# 1                            no                 no              no
# 2                            no                yes              no
# 3                            no                 no              no
# 4                            no                 no             yes
#
# [5 rows x 40 columns]
#
# Services 相關欄位的前幾行：
#                                             Services Services_Housekeeping  \
# 0  ['Bicycle Hire', 'Housekeeping', 'Internet Acc...                   yes
# 1  ['Internet Access', 'Laundry Facilities', 'Tow...                    no
# 2  ['24 Hour Security', 'Bicycle Hire', 'Internet...                    no
# 3  ['Bicycle Hire', 'Housekeeping', 'Internet Acc...                   yes
# 4  ['24 Hour Security', 'Bicycle Hire', 'Internet...                    no
#
#   Services_Laundry_Facilities Services_24_Hour_Security  \
# 0                         yes                        no
# 1                         yes                        no
# 2                         yes                       yes
# 3                         yes                        no
# 4                         yes                       yes
#
#   Services_Late_check-out Services_Express_check-in_/_out  \
# 0                      no                              no
# 1                      no                              no
# 2                      no                              no
# 3                      no                              no
# 4                     yes                              no
#
#   Services_Luggage_Storage Services_Reception_(limited_hours)  \
# 0                      yes                                yes
# 1                       no                                 no
# 2                      yes                                yes
# 3                      yes                                 no
# 4                      yes                                yes
#
#   Services_Tours/Travel_Desk Services_Internet_café Services_Wake-up_calls  \
# 0                         no                     no                     no
# 1                         no                     no                     no
# 2                         no                     no                     no
# 3                         no                     no                     no
# 4                        yes                     no                     no
#
#   Services_Currency_Exchange Services_Towels_for_hire Services_Fax_Service  \
# 0                         no                      yes                   no
# 1                         no                      yes                   no
# 2                         no                      yes                   no
# 3                         no                      yes                   no
# 4                         no                      yes                   no
#
#   Services_24_Hour_Reception Services_Postal_Service Services_Bicycle_Hire  \
# 0                         no                      no                   yes
# 1                         no                      no                    no
# 2                         no                      no                   yes
# 3                         no                      no                   yes
# 4                         no                      no                   yes
#
#   Services_Internet_Access Services_Beauty_Salon
# 0                      yes                    no
# 1                      yes                    no
# 2                      yes                    no
# 3                      yes                    no
# 4                      yes                    no
#
# Food & Drink 相關欄位的前幾行：
#                                         Food & Drink  \
# 0  ['Bar', 'Cafe', 'Meals Available', 'Restaurant...
# 1                                                NaN
# 2  ['Bar', 'Cafe', 'Meals Available', 'Restaurant...
# 3  ['Bar', 'Cafe', 'Tea & Coffee Making Facilities']
# 4  ['Bar', 'Cafe', 'Meals Available', 'Restaurant...
#
#   Food & Drink_Tea_and_Coffee_Making_Facilities Food & Drink_Café  \
# 0                                           yes                no
# 1                                            no                no
# 2                                           yes                no
# 3                                           yes                no
# 4                                           yes                no
#
#   Food & Drink_Cafe Food & Drink_Bar Food & Drink_Restaurant  \
# 0               yes              yes                     yes
# 1                no               no                      no
# 2               yes              yes                     yes
# 3               yes              yes                      no
# 4               yes              yes                     yes
#
#   Food & Drink_Meals_Available Food & Drink_Vending_Machines
# 0                          yes                            no
# 1                           no                            no
# 2                          yes                            no
# 3                           no                            no
# 4                          yes                            no
#
# Entertainment 相關欄位的前幾行：
#                                     Entertainment Entertainment_Games_Room  \
# 0                        ['Board Games', 'Wi-Fi']                       no
# 1                                       ['Wi-Fi']                       no
# 2  ['Board Games', 'PlayStation', 'Wi-Fi', 'Wii']                       no
# 3                                             NaN                       no
# 4                        ['Board Games', 'Wi-Fi']                       no
#
#   Entertainment_Pool_Table Entertainment_Foosball Entertainment_"DVDs"  \
# 0                       no                     no                   no
# 1                       no                     no                   no
# 2                       no                     no                   no
# 3                       no                     no                   no
# 4                       no                     no                   no
#
#   Entertainment_PlayStation Entertainment_Board_Games Entertainment_Wii  \
# 0                        no                       yes                no
# 1                        no                        no                no
# 2                       yes                       yes               yes
# 3                        no                        no                no
# 4                        no                       yes                no
#
#   Entertainment_Wi-Fi
# 0                 yes
# 1                 yes
# 2                 yes
# 3                  no
# 4                 yes

# %%
import pandas as pd

# 讀取CSV文件
df = pd.read_csv('hostels_processed.csv')

# 1. 列出所有column名稱和總數
all_columns = df.columns.tolist()
total_columns = len(all_columns)
print(f"1. 總欄位統計")
print(f"　 總欄位數：{total_columns}")
print("   所有欄位名稱")
for col in all_columns:
    print("  ", col)

print("\n2. 各類型欄位統計")


# 定義要搜尋的前綴
prefixes = ['free_', 'general_', 'service_', 'foodDrink_', 'entertainment_']

# 對每個前綴進行統計
for prefix in prefixes:
    # 找出符合前綴的欄位
    matching_columns = [col for col in all_columns if col.startswith(prefix)]
    
    print(f"\n   {prefix}相關欄位: {len(matching_columns)}個")
    for col in matching_columns:
        print("  ", col)
# Out:
# 1. 總欄位統計
# 　 總欄位數：96
#    所有欄位名稱
#    hostel_name
#    hostel_link
#    city
#    price
#    distance
#    summary_score
#    rating_band
#    value_for_money
#    security
#    location
#    staff
#    atmosphere
#    cleanliness
#    facilities
#    Free
#    General
#    Services
#    Food & Drink
#    Entertainment
#    latitude
#    longitude
#    free_breakfast
#    free_parking
#    free_cityMaps
#    free_wifi
#    free_cityTour
#    free_linen
#    free_internetAccess
#    free_towel
#    free_airportTransfer
#    general_outdoorTerrace
#    general_washingMachine
#    general_cardPhones
#    general_iron
#    general_hairDryers
#    general_utensils
#    general_meetingRoom
#    general_commonRoom
#    general_readingLight
#    general_cableTV
#    general_airConditioning
#    general_jobBoard
#    general_securityLocker
#    general_adaptor
#    general_elevator
#    general_covid19Guide
#    general_microwave
#    general_ceilingFan
#    general_wheelchairFriendly
#    general_flexibleNRR
#    general_bicycleParking
#    general_cooker
#    general_safeDepositBox
#    general_selfCateringFacilities
#    general_keyCardAccess
#    general_bookExchange
#    general_fridge
#    general_fitnessCentre
#    general_hotShower
#    general_dryer
#    general_parking
#    general_bbq
#    general_childPlayArea
#    general_dishwasher
#    general_hotTub
#    service_housekeeping
#    service_laundry
#    service_24HourSecurity
#    service_lateCheckOut
#    service_expressCheckIn
#    service_luggageStorage
#    service_reception
#    service_travelDesk
#    service_internetCafe
#    service_morningCall
#    service_currencyExchange
#    service_fax
#    service_24HourReception
#    service_postal
#    service_bicycleHire
#    service_internetAccess
#    service_beautySalon
#    foodDrink_teaCoffeeMaking
#    foodDrink_cafe
#    foodDrink_bar
#    foodDrink_restaurant
#    foodDrink_Meal
#    foodDrink_vendingMachine
#    entertainment_gameRoom
#    entertainment_poolTable
#    entertainment_foosball
#    entertainment_DVD
#    entertainment_playStation
#    entertainment_boardGame
#    entertainment_wii
#    entertainment_wifi
#
# 2. 各類型欄位統計
#
#    free_相關欄位: 9個
#    free_breakfast
#    free_parking
#    free_cityMaps
#    free_wifi
#    free_cityTour
#    free_linen
#    free_internetAccess
#    free_towel
#    free_airportTransfer
#
#    general_相關欄位: 35個
#    general_outdoorTerrace
#    general_washingMachine
#    general_cardPhones
#    general_iron
#    general_hairDryers
#    general_utensils
#    general_meetingRoom
#    general_commonRoom
#    general_readingLight
#    general_cableTV
#    general_airConditioning
#    general_jobBoard
#    general_securityLocker
#    general_adaptor
#    general_elevator
#    general_covid19Guide
#    general_microwave
#    general_ceilingFan
#    general_wheelchairFriendly
#    general_flexibleNRR
#    general_bicycleParking
#    general_cooker
#    general_safeDepositBox
#    general_selfCateringFacilities
#    general_keyCardAccess
#    general_bookExchange
#    general_fridge
#    general_fitnessCentre
#    general_hotShower
#    general_dryer
#    general_parking
#    general_bbq
#    general_childPlayArea
#    general_dishwasher
#    general_hotTub
#
#    service_相關欄位: 17個
#    service_housekeeping
#    service_laundry
#    service_24HourSecurity
#    service_lateCheckOut
#    service_expressCheckIn
#    service_luggageStorage
#    service_reception
#    service_travelDesk
#    service_internetCafe
#    service_morningCall
#    service_currencyExchange
#    service_fax
#    service_24HourReception
#    service_postal
#    service_bicycleHire
#    service_internetAccess
#    service_beautySalon
#
#    foodDrink_相關欄位: 6個
#    foodDrink_teaCoffeeMaking
#    foodDrink_cafe
#    foodDrink_bar
#    foodDrink_restaurant
#    foodDrink_Meal
#    foodDrink_vendingMachine
#
#    entertainment_相關欄位: 8個
#    entertainment_gameRoom
#    entertainment_poolTable
#    entertainment_foosball
#    entertainment_DVD
#    entertainment_playStation
#    entertainment_boardGame
#    entertainment_wii
#    entertainment_wifi
